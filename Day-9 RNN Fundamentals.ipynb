# %% [markdown]
# # Recurrent Neural Networks (RNNs)

# %% [markdown]
# ![Screenshot%20from%202025-07-19%2001-06-13.jpeg](attachment:Screenshot%20from%202025-07-19%2001-06-13.jpeg)

# %% [markdown]
# Recurrent Connections: RNNs have recurrent connections that allow information to persist across different time steps in a sequence. This means that information from previous inputs is considered when processing the current input.
#
#     Shared Parameters: The same set of weights and biases are applied at each time step. This allows the network to use the same computation for different elements of the sequence.
#
#     Time Dependency: RNNs are well-suited for tasks where the order or temporal dependency of data matters, such as time series prediction, language modeling, and speech recognition.

# %% [markdown]
# Recurrent Neural Networks (RNNs) are a type of neural network architecture that is particularly well-suited for tasks involving sequential data. Unlike feedforward neural networks, which process data in fixed-size chunks, RNNs can handle input sequences of arbitrary length.

# %% [markdown]
# ![Screenshot%20from%202025-07-19%2000-08-31.jpeg](attachment:Screenshot%20from%202025-07-19%2000-08-31.jpeg)

# %% [markdown]
# # Forward Propagation in RNN

# %% [markdown]
# ![Screenshot%20from%202025-07-19%2000-46-55.jpeg](attachment:Screenshot%20from%202025-07-19%2000-46-55.jpeg)

# %% [markdown]
# # Backpropagation in RNN

# %% [markdown]
# Our main aim is to reduce loss function (that we calculated using forward propagation), take derivative using chain rule and update weights w.r.t time and do it for many number of epochs automatically you will be able to reach global minima and that is the pt. where training of RNN model will stop.
#
# In below image backward propagation is shown by <- (backward arrow)!

# %% [markdown]
# ![Screenshot%20from%202025-07-20%2000-30-19.jpeg](attachment:Screenshot%20from%202025-07-20%2000-30-19.jpeg)

# %% [markdown]
# # Problems in simple RNN model

# %% [markdown]
# **1) Vanishing Gradient Problem**:
# Derivative is continuously taking place and when u reach at the point where we have shown Oo(in image) in backward direction , it(**derivative value) will become very small(or almost negligible)** that we won't be able to reach global minima . Suppose activation function we are taking here is sigmoid(value lies b/w 0 to 1).

# %% [markdown]
# ![Screenshot%20from%202025-07-20%2001-00-30.jpeg](attachment:Screenshot%20from%202025-07-20%2001-00-30.jpeg)

# %% [markdown]
# ![Screenshot%20from%202025-07-20%2001-16-34%281%29.jpeg](attachment:Screenshot%20from%202025-07-20%2001-16-34%281%29.jpeg)

# %% [markdown]
# **2)Exploding gradient problem:**
# If we use activation function other than sigmoid, let's say ReLu then suppose its **derivative >1** and when u reach at the point where we have shown Oo(in image) in backward direction then it creates this kind of problem.
#
# In this you will have huge change , it will keep on rotating here itself as shown in below image, but will never reach to global minima.

# %% [markdown]
# ![Screenshot%20from%202025-07-20%2001-27-35.jpeg](attachment:Screenshot%20from%202025-07-20%2001-27-35.jpeg)

# %% [markdown]
# **Note:** To solve these 2 problems of RNN we proceed with LSTM(Long Short Term Memory)
